# %% [markdown]
# # Hypothesis 1
# ### Friedman test performed on 3 frozen models since there are 3 comparisons and since each model saw the same data splits

# %%
# !pip install scikit-posthocs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 41.8 MB/s  0:00:00eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [scikit-posthocs] [statsmodels]
# ...

# %%
from scipy import stats
import scikit_posthocs as sp
import pandas as pd
from scipy.stats import wilcoxon

# %%
#n=50 for this test
#macro F1 scores test data
roberta_frozen = [0.2651226286306077,
    0.3041922290388548,
    0.29922027290448344,
    0.24600220567962502,
    0.2709255745308876,
    0.33763291724456773,
    0.27580314422419683,
    0.30441169719506034,
    0.34508572808500365,
    0.29964949800986157,
    0.2523364485981308,
    0.28129890453834117,
    0.2523364485981308,
    0.2892078681552366,
    0.3130661591061295,
    0.26041148166583705,
    0.3128323108384458,
    0.3001763668430335,
    0.3470209339774557,
    0.33012583271650625,
    0.29106753812636166,
    0.30354891010628715,
    0.28129890453834117,
    0.2523364485981308,
    0.23414634146341462,
    0.2867279471053056,
    0.2975908372827804,
    0.24842767295597482,
    0.26041064198958935,
    0.30737114886265476,
    0.2523364485981308,
    0.2947666195190948,
    0.28129890453834117,
    0.28576131687242795,
    0.29419354838709677,
    0.29772773382024753,
    0.3075448445844174,
    0.33196480938416423,
    0.3263135041250543,
    0.31475409836065577,
    0.3054466230936819,
    0.30926507284874827,
    0.2913993636885203,
    0.28896544524480633,
    0.2930049102471223,
    0.2523364485981308,
    0.2586808861804101,
    0.2563222543352601,
    0.2745484400656814,
    0.27331575161831695]
pubmedbert_frozen = [0.3273436115541379,
    0.3095975232198142,
    0.34815932933080623,
    0.32602488353146825,
    0.3056408770404713,
    0.3180923699578543,
    0.3192951728896319,
    0.3615714858974148,
    0.4213836477987421,
    0.31804923981443206,
    0.41396797262533386,
    0.36887760834936184,
    0.3047320534587088,
    0.31511304552816427,
    0.3401328380051784,
    0.347338282414898,
    0.31007401200949586,
    0.35309868875086264,
    0.28122605363984676,
    0.36837871450874543,
    0.3289329344303166,
    0.3032170332972713,
    0.34133517912782124,
    0.2918266272917435,
    0.3168084352294878,
    0.27113135003953864,
    0.2926096433624118,
    0.3338852180957444,
    0.3696946041208336,
    0.26524542702987236,
    0.3417318734722805,
    0.41406864397258736,
    0.3707118162215557,
    0.30502364066193854,
    0.34471141622171375,
    0.3231987650592302,
    0.3041231227294066,
    0.4009979195317183,
    0.38651806529807825,
    0.3339455658604595,
    0.3011204481792717,
    0.3934145564580347,
    0.34266296515420436,
    0.35250309683801256,
    0.32132289326557467,
    0.3204446270139701,
    0.3157487922705314,
    0.31469931469931467,
    0.4125352037834104,
    0.3267886389528489]
deberta_v3_frozen = [0.24353836644036542,
    0.31398373983739836,
    0.3547415547415547,
    0.3388956722290056,
    0.3249360699303037,
    0.30534732633683154,
    0.3006124506668971,
    0.3240358557431728,
    0.31695459384246566,
    0.2947619047619048,
    0.25,
    0.29068376068376073,
    0.3639073969508752,
    0.3154471544715447,
    0.3078858719915581,
    0.3384405856315969,
    0.3053473263368316,
    0.30982738780207136,
    0.25981981981981983,
    0.4013790600616948,
    0.35848533377702907,
    0.3675697865353038,
    0.2924741814985718,
    0.2325348413606134,
    0.31992483481845185,
    0.25629135874027914,
    0.2556408070474567,
    0.28363406141183917,
    0.42173116738334127,
    0.1546020117448689,
    0.2835795551027339,
    0.3192961287078934,
    0.3046232873602052,
    0.29329069444787864,
    0.2525863284002819,
    0.23196399593915126,
    0.30001869836828576,
    0.33001207729468596,
    0.3265096008471516,
    0.2764563781512934,
    0.3638791228653222,
    0.26925180213770816,
    0.23024054982817868,
    0.27428912783751497,
    0.35147867727949267,
    0.3160971055088702,
    0.2985941985941986,
    0.3140626974210667,
    0.3047080979284369,
    0.3083566324945635]

#run the Friedman Test
stat, p_value = stats.friedmanchisquare(deberta_v3_frozen, pubmedbert_frozen, roberta_frozen)

print(f"Friedman Q-statistic: {stat:.4f}")
print(f"P-value: {p_value:.4f}")
# Out:
# Friedman Q-statistic: 25.4800
# P-value: 0.0000

# %% [markdown]
# ### Nemenyi post hoc test

# %%
df = pd.DataFrame({
    "DeBERTa_v3_frozen": deberta_v3_frozen,
    "PubMedBERT_frozen": pubmedbert_frozen,
    "RoBERTa_frozen": roberta_frozen
})

nemenyi_results = sp.posthoc_nemenyi_friedman(df)

print("Friedman p-value:", p_value)
print("\nNemenyi post-hoc p-values:")
print(nemenyi_results)
# Out:
# Friedman p-value: 2.9314892136891066e-06
#
# Nemenyi post-hoc p-values:
#                    DeBERTa_v3_frozen  PubMedBERT_frozen  RoBERTa_frozen
# DeBERTa_v3_frozen           1.000000           0.001352        0.340875
# PubMedBERT_frozen           0.001352           1.000000        0.000003
# RoBERTa_frozen              0.340875           0.000003        1.000000

# %% [markdown]
# ## Wilcoxon Signed Rank tests
# Comparison to determine if LoRA improved baseline

# %% [markdown]
# ### Roberta

# %%
#n=50 for this test
#macro F1 scores test data

roberta_frozen = [
0.2651226286306080,
0.3041922290388550,
0.29922027290448300,
0.24600220567962500,
0.2709255745308880,
0.33763291724456800,
0.27580314422419700,
0.30441169719506000,
0.34508572808500400,
0.29964949800986200,
0.2523364485981310,
0.28129890453834100,
0.2523364485981310,
0.2892078681552370,
0.3130661591061300,
0.26041148166583700,
0.3128323108384460,
0.3001763668430340,
0.3470209339774560,
0.33012583271650600,
0.29106753812636200,
0.30354891010628700,
0.28129890453834100,
0.2523364485981310,
0.23414634146341500,
0.2867279471053060,
0.2975908372827800,
0.24842767295597500,
0.26041064198958900,
0.30737114886265500
]

roberta_lora = [
0.4735113209689480,
0.5389978213507630,
0.43007361328405000,
0.4396341865654950,
0.4294873960620910,
0.45609945609945600,
0.4457289002557550,
0.41571247387506500,
0.42536573083217900,
0.41731474688187800,
0.31701807005521000,
0.5067538126361660,
0.45705394040717700,
0.4238861963066400,
0.4753938070430310,
0.4229238588415800,
0.4121692515552060,
0.4614449580551280,
0.4028571428571430,
0.40467239766602800,
0.4685579820750660,
0.4098304095547180,
0.4552820285355220,
0.42815531871617000,
0.5037184889480300,
0.41209540705696800,
0.49021177395798200,
0.4127302436125970,
0.3489683080685130,
0.4279768570362080
]


stat, p_value = wilcoxon(roberta_frozen, roberta_lora)

print(f"Wilcoxon statistic: {stat}")
print(f"p-value: {p_value}")
# Out:
# Wilcoxon statistic: 0.0
# p-value: 1.862645149230957e-09

# %% [markdown]
# ### PubMedBERT

# %%
pubmedbert_frozen = [
0.3273436115541380,
0.3095975232198140,
0.34815932933080600,
0.32602488353146800,
0.3056408770404710,
0.3180923699578540,
0.3192951728896320,
0.3615714858974150,
0.4213836477987420,
0.31804923981443200,
0.41396797262533400,
0.36887760834936200,
0.3047320534587090,
0.31511304552816400,
0.3401328380051780,
0.347338282414898,
0.31007401200949600,
0.35309868875086300,
0.28122605363984700,
0.36837871450874500,
0.3289329344303170,
0.3032170332972710,
0.34133517912782100,
0.2918266272917440,
0.3168084352294880,
0.27113135003953900,
0.2926096433624120,
0.3338852180957440,
0.3696946041208340,
0.26524542702987200
]

pubmedbert_lora = [
0.5054086273124640,
0.4189167470266800,
0.4361384335154830,
0.46867215365984900,
0.3832775078234340,
0.4511444793954140,
0.4035497239831610,
0.5033960871170170,
0.46297012679991400,
0.42230158038885500,
0.41789449629981200,
0.45418779971716300,
0.47500845485109500,
0.4873566427059340,
0.464552501761804,
0.40665024630541900,
0.4825374891243160,
0.4631093544137020,
0.536837376460018,
0.3981342662002330,
0.46205601627288400,
0.5011831275720160,
0.43504111321948100,
0.44832925497352500,
0.4111471861471860,
0.4932298444568380,
0.4506476920270020,
0.5488138952031240,
0.4038044132029980,
0.41386083052749700
]

stat, p_value = wilcoxon(pubmedbert_frozen, pubmedbert_lora)

print(f"Wilcoxon statistic: {stat}")
print(f"p-value: {p_value}")
# Out:
# Wilcoxon statistic: 0.0
# p-value: 1.862645149230957e-09

# %% [markdown]
# ### Deberta

# %%
deberta_frozen = [
0.24353836644036500,
0.31398373983739800,
0.3547415547415550,
0.3388956722290060,
0.3249360699303040,
0.30534732633683200,
0.3006124506668970,
0.3240358557431730,
0.31695459384246600,
0.2947619047619050,
0.25,
0.29068376068376100,
0.3639073969508750,
0.3154471544715450,
0.3078858719915580,
0.3384405856315970,
0.3053473263368320,
0.30982738780207100,
0.25981981981982000,
0.4013790600616950,
0.35848533377702900,
0.3675697865353040,
0.2924741814985720,
0.2325348413606130,
0.31992483481845200,
0.25629135874027900,
0.2556408070474570,
0.28363406141183900,
0.42173116738334100,
0.1546020117448690
]

deberta_lora = [
0.2567481538069770,
0.32643427741467000,
0.3239554991232840,
0.27585365853658500,
0.26735972277755600,
0.27738627465838200,
0.28571428571428600,
0.2989766081871350,
0.2669934640522880,
0.25391545391545400,
0.2834743653558990,
0.24322783005417700,
0.30653724904596000,
0.30052356020942400,
0.3690862109466760,
0.32229709493860400,
0.3090984252477100,
0.3592391864692460,
0.30320203493809100,
0.3476559483047140,
0.2996836353178030,
0.34477468839884900,
0.38788526288526300,
0.24613534867743000,
0.3217098461351340,
0.2851716185049520,
0.29630524028012600,
0.30469931674751000,
0.2680701754385970,
0.23495970063327600
]

stat, p_value = wilcoxon(deberta_frozen, deberta_lora)

print(f"Wilcoxon statistic: {stat}")
print(f"p-value: {p_value}")
# Out:
# Wilcoxon statistic: 189.0
# p-value: 0.3817984350025654

# %% [markdown]
# ### Roberta Frozen vs Full

# %%
roberta_full = [
0.4775688603001820,
0.4481901966841730,
0.393939393939394,
0.45740839688476500,
0.34045515394913000,
0.44154589371980700,
0.4285380116959060,
0.40871460774356600,
0.3883101227985930,
0.3912578162010390,
0.448829302332487,
0.40187725112949400,
0.4286120545798930,
0.3934291083227250,
0.4310288589563290,
0.43113969981857200,
0.40847481642035200,
0.361245828698554,
0.48148970506130900,
0.4931776392769300,
0.4658255114911460,
0.38131125733164000,
0.42466153127917800,
0.4109360199776110,
0.3898764178093790,
0.33174678724416900,
0.4941148246442660,
0.41696721819421200,
0.4192482199039580,
0.46705108301914700
]


stat, p_value = wilcoxon(roberta_frozen, roberta_full)

print(f"Wilcoxon statistic: {stat}")
print(f"p-value: {p_value}")
# Out:
# Wilcoxon statistic: 0.0
# p-value: 1.862645149230957e-09

# %% [markdown]
# ### Pubmedbert frozen vs full

# %%
pubmedbert_full = [
0.4093062982768870,
0.3134822167080230,
0.42979221709297500,
0.4203921568627450,
0.37779892360897900,
0.42181334094042700,
0.4289166044842410,
0.3521811825505400,
0.4358526141042340,
0.5028591574123040,
0.4391010254076790,
0.4402536231884060,
0.4614689153274880,
0.48443327677913100,
0.46436507936507900,
0.40154230476811100,
0.4578504519517250,
0.39104741127254700,
0.46365203625069600,
0.45905818706627600,
0.4301417659908230,
0.38125709760325100,
0.4132519616390580,
0.3706582295893800,
0.49869586251866800,
0.40205604188655000,
0.4267204039561760,
0.5151927437641720,
0.32885375494071100,
0.540462363093548
]


stat, p_value = wilcoxon(pubmedbert_frozen, pubmedbert_full)

print(f"Wilcoxon statistic: {stat}")
print(f"p-value: {p_value}")
# Out:
# Wilcoxon statistic: 8.0
# p-value: 4.6566128730773926e-08
